# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\programdata\anaconda3\lib\site-packages (0.0)
# ...

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
# First let's run every factor, setting koi_disposition as target

#pull target into y; everything else into X
y = df["koi_disposition"]
X = df.drop("koi_disposition", axis=1)
X.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
#since y is text...
y.unique()
# Out:
# array(['CONFIRMED', 'FALSE POSITIVE', 'CANDIDATE'], dtype=object)

# %%
# let's encode the y target text values
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
encoded_y = LabelEncoder().fit(df['koi_disposition'])
y = encoded_y.transform(df['koi_disposition'])

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
# split and scale X data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
# 6370              0              1              0              1    0.733726
# 2879              1              0              0              0    7.652707
# 107               0              0              0              0    7.953547
# 29                0              0              0              0    4.959319
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6122     7.380000e-05    -7.380000e-05   133.077240          0.008440
# 6370     6.060000e-06    -6.060000e-06   132.020050          0.007950
# 2879     6.540000e-05    -6.540000e-05   134.460380          0.006190
# 107      1.910000e-05    -1.910000e-05   174.662240          0.001820
# 29       5.150000e-07    -5.150000e-07   172.258529          0.000083
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.ensemble import RandomForestClassifier
modelRF = RandomForestClassifier(n_estimators=200)
modelRF.fit(X_train_scaled, y_train)

print(f"Training Data Score: {modelRF.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {modelRF.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.8998855835240275

# %%
# since it's a RandomForrest, let's rank the features
feature_names = X.columns.tolist()
preSelected_features = sorted(zip(modelRF.feature_importances_, feature_names), reverse=True)
ranked_features = pd.DataFrame(preSelected_features, columns=['Score', 'Feature'])
ranked_features = ranked_features.set_index('Feature')
ranked_features
# Out:
#                       Score
# Feature
# koi_fpflag_co      0.105424
# koi_fpflag_nt      0.097739
# koi_fpflag_ss      0.069483
# koi_model_snr      0.055766
# koi_prad           0.045393
# koi_fpflag_ec      0.036369
# koi_duration_err1  0.033762
# koi_prad_err2      0.032368
# koi_steff_err1     0.031079
# koi_duration_err2  0.030966
# koi_prad_err1      0.030874
# koi_steff_err2     0.026082
# koi_time0bk_err2   0.025502
# koi_depth          0.023896
# koi_period         0.022951
# koi_time0bk_err1   0.022137
# koi_duration       0.021648
# koi_insol_err1     0.020889
# koi_period_err1    0.019749
# koi_impact         0.019068
# koi_period_err2    0.018750
# koi_teq            0.015931
# koi_insol_err2     0.015323
# koi_insol          0.014727
# koi_depth_err2     0.013099
# koi_time0bk        0.013061
# koi_depth_err1     0.012789
# ra                 0.012425
# dec                0.011445
# koi_srad_err1      0.010852
# koi_slogg_err2     0.010737
# koi_impact_err1    0.010736
# ...

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
#find the 
from pprint import pprint
print('Parameters currently in use:\n')
pprint(modelRF.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 200,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {
    'bootstrap': [True],
    'max_depth': [90, 100, 110],
    'max_features': [1, 2, 3],
    'min_samples_leaf': [1, 2, 3],
    'min_samples_split': [4, 6, 8],
    'n_estimators': [100, 200, 300]}

grid = GridSearchCV(estimator = modelRF, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)

# %%
# Train the model with GridSearch
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 243 candidates, totalling 729 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:   35.2s
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 729 out of 729 | elapsed:  1.3min finished
# GridSearchCV(cv=3, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
# ...

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'bootstrap': True, 'max_depth': 90, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.8800290527468468

# %%
# Make predictions with the hypertuned model
predictions = grid.predict(X_test)

print('Random Forests')
print('Test Accuracy: %.3f' % grid.score(X_test, y_test))

# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
# Random Forests
# Test Accuracy: 0.888
#               precision    recall  f1-score   support
#
#            0       0.83      0.72      0.77       411
#            1       0.84      0.85      0.84       484
#            2       0.94      0.99      0.97       853
#
#     accuracy                           0.89      1748
#    macro avg       0.87      0.85      0.86      1748
# weighted avg       0.89      0.89      0.89      1748

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'matthewDebnarRF.sav'
joblib.dump(modelRF, filename)
# Out:
# ['matthewDebnarRF.sav']
